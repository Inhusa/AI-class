# %% [markdown]
# <a href="https://colab.research.google.com/github/Inhusa/AI-class/blob/main/DL_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# 데이터 로드

# %%
url = "https://raw.githubusercontent.com/Inhusa/AI-class/refs/heads/main/4%20week/wine.csv"
df = pd.read_csv(url)
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine                  178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Acl                   178 non-null    float64
#  5   Mg                    178 non-null    int64
#  6   Phenols               178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanth               178 non-null    float64
#  10  Color.int             178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD                    178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %% [markdown]
# 결측치 유무 확인

# %%
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %% [markdown]
# 결측치 제거

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %% [markdown]
# 상관관계 혼동행렬

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Wine Grade 각 Feature 별 분포 시각화

# %%
plt.figure(figsize=(10, 10))
for i, feature in enumerate(df.columns[1:]):  # Wine 제외
    plt.subplot(4, 4, i + 1)
    sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
    plt.title(feature)
    plt.xlabel('Wine Grade')
    plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')
# <ipython-input-11-01eba8967551>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Wine', y=feature, palette='muted', inner='quartile')

# %% [markdown]
# - 시각화 했을 때 보이는 높은 상관 관계를 갖는 feature는 Acl, Phenols , Flavanoids, Nonflavanoid.phenols, Proanth, Hue, OD 인 듯하다
# - 1,2,3이 순차적으로 나열된형태를 가지거나 역순차적인 순서를 나타내야하는데 이 feature들이 그 결과 값을 잘 반영한 듯하다.
# - 상관관계 혼동행렬에서 상관관계를 Heatmap으로 시각화했는데 이것은 그 절대값이 크면 상관관계가 크지 않나 싶다

# %%
X=df.drop('Wine',axis=1)
X.head()
# Out:
#    Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
y=df['Wine']
y.value_counts()
# Out:
# Wine
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Wine, dtype: int64

# %%
Y = pd.get_dummies(y).values
X = X.values

# %%
X
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %% [markdown]
# ##### 데이터 분할

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# #### 하이퍼파라미터 튜닝 (은닉층 및 유닛 수 / 학습률 / 배치 크기 / 에폭 수)
# - 은닉층 및 유닛 수는 모델의 복잡도 관리
# - 최적화 알고리즘은 Adam으로 고정
# - 손실함수는 카테고리형으로 고정
# - 배치크기 / 학습률 / 에폭 수/ 은닉층 및 유닛 수를 조정해서 비교

# %% [markdown]
# ##### 하이퍼파라미터 튜닝 모델 각각 컴파일

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model_base = Sequential() # 기본 구조 은닉층 1 모양 없음

model_base.add(Dense(9,input_shape=(13,),activation='relu'))
model_base.add(Dense(6,activation='relu'))
model_base.add(Dense(3,activation='softmax'))

model_base.compile(optimizer=Adam(learning_rate=0.05),loss='categorical_crossentropy',metrics=['accuracy'])

model_base.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_97 (Dense)                     │ (None, 9)                   │             126 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_98 (Dense)                     │ (None, 6)                   │              60 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_99 (Dense)                     │ (None, 3)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 207 (828.00 B)
#  Trainable params: 207 (828.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model_hidlayer = Sequential() # 은닉층 수 조정 (유닛 수: 마름모 꼴)+ 학습률 조절

model_hidlayer.add(Dense(3,input_shape=(13,),activation='relu'))
model_hidlayer.add(Dense(32,activation='relu'))
model_hidlayer.add(Dense(64,activation='relu'))
model_hidlayer.add(Dense(128,activation='relu'))
model_hidlayer.add(Dense(64,activation='relu'))
model_hidlayer.add(Dense(32,activation='relu'))
model_hidlayer.add(Dense(3,activation='softmax')) # 은닉층 수 3

model_hidlayer.compile(optimizer=Adam(learning_rate=5e-3),loss='categorical_crossentropy',metrics=['accuracy'])

model_hidlayer.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_131 (Dense)                    │ (None, 3)                   │              42 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_132 (Dense)                    │ (None, 32)                  │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_133 (Dense)                    │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_134 (Dense)                    │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_135 (Dense)                    │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_136 (Dense)                    │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,621 (33.68 KB)
#  Trainable params: 8,621 (33.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_batchsize = Sequential() # 은닉층 수 조정 + 배치 수 조절 + 학습률 조절

model_batchsize.add(Dense(3,input_shape=(13,),activation='relu'))
model_batchsize.add(Dense(32,activation='relu'))
model_batchsize.add(Dense(64,activation='relu'))
model_batchsize.add(Dense(64,activation='relu'))
model_batchsize.add(Dense(32,activation='relu'))
model_batchsize.add(Dense(3,activation='softmax')) # 은닉층 수 3

model_batchsize.compile(optimizer=Adam(learning_rate=5e-3),loss='categorical_crossentropy',metrics=['accuracy'])

model_batchsize.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_125 (Dense)                    │ (None, 3)                   │              42 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_126 (Dense)                    │ (None, 32)                  │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_127 (Dense)                    │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_128 (Dense)                    │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_129 (Dense)                    │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_130 (Dense)                    │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,621 (33.68 KB)
#  Trainable params: 8,621 (33.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (142, 13)
# (36, 13)

# %% [markdown]
# ##### 모델 별 학습

# %% [markdown]
# 가장 기본적인 모델
# - 은닉층 = 1
# - ecpochs = 30
# - batch_size = 30
# - 학습률 = 0.04

# %%
base_history=model_base.fit(x=X_train, y=y_train, epochs=30, batch_size=32, validation_data= (X_test,y_test))
y_pred = model_base.predict(X_test)

y_test_base = np.argmax(y_test,axis=1)
y_pred_base = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8385 - loss: 0.4060 - val_accuracy: 0.6389 - val_loss: 0.8670
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8195 - loss: 0.5001 - val_accuracy: 0.8333 - val_loss: 0.3928
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8664 - loss: 0.4008 - val_accuracy: 0.8056 - val_loss: 0.5417
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6667 - loss: 0.6775 - val_accuracy: 0.5833 - val_loss: 1.0309
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7289 - loss: 0.6214 - val_accuracy: 0.7778 - val_loss: 0.5541
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7024 - loss: 0.6073 - val_accuracy: 0.6667 - val_loss: 0.7792
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8616 - loss: 0.4029 - val_accuracy: 0.8611 - val_loss: 0.4277
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7877 - loss: 0.4282 - val_accuracy: 0.8333 - val_loss: 0.4135
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8775 - loss: 0.3276 - val_accuracy: 0.8611 - val_loss: 0.3917
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8926 - loss: 0.3108 - val_accuracy: 0.8611 - val_loss: 0.3875
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9027 - loss: 0.3210 - val_accuracy: 0.8333 - val_loss: 0.4153
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8432 - loss: 0.3661 - val_accuracy: 0.8333 - val_loss: 0.4006
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9145 - loss: 0.3070 - val_accuracy: 0.8333 - val_loss: 0.4019
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8159 - loss: 0.3849 - val_accuracy: 0.7778 - val_loss: 0.5048
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8325 - loss: 0.4185 - val_accuracy: 0.7778 - val_loss: 0.5021
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8512 - loss: 0.3784 - val_accuracy: 0.8611 - val_loss: 0.3801
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9008 - loss: 0.3094 - val_accuracy: 0.7222 - val_loss: 0.6429
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8508 - loss: 0.4225 - val_accuracy: 0.8611 - val_loss: 0.3733
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8926 - loss: 0.3641 - val_accuracy: 0.8611 - val_loss: 0.3826
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8477 - loss: 0.3627 - val_accuracy: 0.8611 - val_loss: 0.3715
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8366 - loss: 0.3825 - val_accuracy: 0.7222 - val_loss: 0.5941
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8326 - loss: 0.4276 - val_accuracy: 0.8611 - val_loss: 0.4380
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8100 - loss: 0.4336 - val_accuracy: 0.8611 - val_loss: 0.3957
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8938 - loss: 0.3041 - val_accuracy: 0.8611 - val_loss: 0.3740
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8709 - loss: 0.3389 - val_accuracy: 0.8611 - val_loss: 0.3599
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8890 - loss: 0.3220 - val_accuracy: 0.8611 - val_loss: 0.4126
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8676 - loss: 0.2884 - val_accuracy: 0.8333 - val_loss: 0.4487
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8121 - loss: 0.4376 - val_accuracy: 0.8611 - val_loss: 0.4199
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8772 - loss: 0.3030 - val_accuracy: 0.8333 - val_loss: 0.4708
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8687 - loss: 0.3549 - val_accuracy: 0.8333 - val_loss: 0.4449
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# 하이퍼 파라미터 中 은닉층및 유닛 수 마름모 꼴로 수정  + 학습률 변경
# - 은닉층 = 3
# - ecpochs = 30
# - batch_size = 32
# - 학습률 = 5e-1

# %%
hidlayer_history=model_hidlayer.fit(x=X_train, y=y_train, epochs=30, batch_size=32, validation_data= (X_test,y_test))
y_pred = model_hidlayer.predict(X_test)

y_test_hidlayer = np.argmax(y_test,axis=1)
y_pred_hidlayer = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6590 - loss: 0.6549 - val_accuracy: 0.7500 - val_loss: 0.5808
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6956 - loss: 0.6178 - val_accuracy: 0.7500 - val_loss: 0.5825
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6766 - loss: 0.6419 - val_accuracy: 0.6944 - val_loss: 0.6185
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6563 - loss: 0.6425 - val_accuracy: 0.6389 - val_loss: 0.6033
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6931 - loss: 0.6400 - val_accuracy: 0.6944 - val_loss: 0.6084
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6752 - loss: 0.6905 - val_accuracy: 0.7222 - val_loss: 0.5918
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6733 - loss: 0.6301 - val_accuracy: 0.7500 - val_loss: 0.5835
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6516 - loss: 0.6652 - val_accuracy: 0.7222 - val_loss: 0.5934
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6121 - loss: 0.7080 - val_accuracy: 0.6944 - val_loss: 0.6089
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6281 - loss: 0.6859 - val_accuracy: 0.7500 - val_loss: 0.5729
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6838 - loss: 0.6144 - val_accuracy: 0.6944 - val_loss: 0.5813
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6944 - loss: 0.6803 - val_accuracy: 0.6944 - val_loss: 0.5794
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6819 - loss: 0.6661 - val_accuracy: 0.6667 - val_loss: 0.6161
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6215 - loss: 0.6871 - val_accuracy: 0.6944 - val_loss: 0.6265
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6853 - loss: 0.6540 - val_accuracy: 0.7222 - val_loss: 0.5962
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6670 - loss: 0.6710 - val_accuracy: 0.7500 - val_loss: 0.5756
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6963 - loss: 0.6312 - val_accuracy: 0.7500 - val_loss: 0.5789
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6819 - loss: 0.6273 - val_accuracy: 0.7500 - val_loss: 0.5779
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7202 - loss: 0.5677 - val_accuracy: 0.7222 - val_loss: 0.5853
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6603 - loss: 0.6654 - val_accuracy: 0.6667 - val_loss: 0.6423
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6866 - loss: 0.6543 - val_accuracy: 0.6944 - val_loss: 0.6021
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6445 - loss: 0.6860 - val_accuracy: 0.7222 - val_loss: 0.5894
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6542 - loss: 0.7092 - val_accuracy: 0.6944 - val_loss: 0.5791
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6324 - loss: 0.6526 - val_accuracy: 0.6944 - val_loss: 0.5871
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6843 - loss: 0.6131 - val_accuracy: 0.7222 - val_loss: 0.5725
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6948 - loss: 0.5967 - val_accuracy: 0.6944 - val_loss: 0.5724
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7166 - loss: 0.6088 - val_accuracy: 0.6944 - val_loss: 0.5866
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6957 - loss: 0.6317 - val_accuracy: 0.6944 - val_loss: 0.5926
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6813 - loss: 0.6191 - val_accuracy: 0.6944 - val_loss: 0.5797
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7073 - loss: 0.6391 - val_accuracy: 0.7222 - val_loss: 0.5665
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# 하이퍼 파라미터 전체적 조정  ( 은닉층 : 정사각형 꼴 배치수 늘리고, 학습률 늘리고)
# - 은닉층 = 3
# - ecpochs = 100
# - batch_size = 100
# - 학습률 = 5e-3

# %%
batch_history=model_batchsize.fit(x=X_train, y=y_train, epochs=100, batch_size=100, validation_data= (X_test,y_test))
y_pred = model_batchsize.predict(X_test)

y_test_batch = np.argmax(y_test,axis=1)
y_pred_batch = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8990 - loss: 0.2601 - val_accuracy: 0.9444 - val_loss: 0.2165
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8782 - loss: 0.2867 - val_accuracy: 0.9167 - val_loss: 0.2387
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9137 - loss: 0.2405 - val_accuracy: 0.9444 - val_loss: 0.2652
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9103 - loss: 0.2682 - val_accuracy: 0.9722 - val_loss: 0.2207
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9184 - loss: 0.2694 - val_accuracy: 0.9167 - val_loss: 0.2180
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9143 - loss: 0.2460 - val_accuracy: 0.9444 - val_loss: 0.2057
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9237 - loss: 0.2424 - val_accuracy: 0.9722 - val_loss: 0.1908
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9331 - loss: 0.2436 - val_accuracy: 0.9444 - val_loss: 0.2664
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8769 - loss: 0.2592 - val_accuracy: 0.9722 - val_loss: 0.1901
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9505 - loss: 0.2187 - val_accuracy: 0.9167 - val_loss: 0.2376
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8708 - loss: 0.2683 - val_accuracy: 0.9167 - val_loss: 0.2186
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9184 - loss: 0.2224 - val_accuracy: 0.9722 - val_loss: 0.1942
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9250 - loss: 0.2499 - val_accuracy: 0.9444 - val_loss: 0.2473
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9103 - loss: 0.2397 - val_accuracy: 0.9444 - val_loss: 0.1951
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9250 - loss: 0.2402 - val_accuracy: 0.9444 - val_loss: 0.2066
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9103 - loss: 0.2444 - val_accuracy: 0.9444 - val_loss: 0.2611
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8896 - loss: 0.2457 - val_accuracy: 0.9722 - val_loss: 0.1833
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9264 - loss: 0.2184 - val_accuracy: 0.9444 - val_loss: 0.1761
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9571 - loss: 0.2028 - val_accuracy: 0.9444 - val_loss: 0.1853
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9471 - loss: 0.1985 - val_accuracy: 0.9722 - val_loss: 0.1696
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9377 - loss: 0.2110 - val_accuracy: 0.9722 - val_loss: 0.1728
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9558 - loss: 0.1933 - val_accuracy: 0.9722 - val_loss: 0.1656
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9364 - loss: 0.1983 - val_accuracy: 0.9167 - val_loss: 0.2101
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9170 - loss: 0.1958 - val_accuracy: 0.9444 - val_loss: 0.1615
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9571 - loss: 0.1863 - val_accuracy: 0.9722 - val_loss: 0.1624
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9377 - loss: 0.1901 - val_accuracy: 0.9444 - val_loss: 0.2375
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8862 - loss: 0.2268 - val_accuracy: 0.9444 - val_loss: 0.1786
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9391 - loss: 0.1899 - val_accuracy: 0.9444 - val_loss: 0.1555
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9311 - loss: 0.2108 - val_accuracy: 0.9444 - val_loss: 0.2029
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9344 - loss: 0.2011 - val_accuracy: 0.9444 - val_loss: 0.1846
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9344 - loss: 0.1866 - val_accuracy: 0.9444 - val_loss: 0.1568
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9311 - loss: 0.1983 - val_accuracy: 0.9444 - val_loss: 0.1794
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9505 - loss: 0.1728 - val_accuracy: 0.9722 - val_loss: 0.1532
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9203 - loss: 0.1926 - val_accuracy: 0.9444 - val_loss: 0.1991
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9176 - loss: 0.2020 - val_accuracy: 0.9444 - val_loss: 0.1586
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9190 - loss: 0.2017 - val_accuracy: 0.9722 - val_loss: 0.1634
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9377 - loss: 0.1758 - val_accuracy: 0.8611 - val_loss: 0.2858
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9037 - loss: 0.2329 - val_accuracy: 0.9167 - val_loss: 0.1740
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8715 - loss: 0.2861 - val_accuracy: 0.9722 - val_loss: 0.1676
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9458 - loss: 0.1659 - val_accuracy: 0.9444 - val_loss: 0.2032
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9231 - loss: 0.1838 - val_accuracy: 0.9444 - val_loss: 0.1411
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9511 - loss: 0.1756 - val_accuracy: 0.9444 - val_loss: 0.2184
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9156 - loss: 0.1980 - val_accuracy: 0.9167 - val_loss: 0.1864
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9424 - loss: 0.1639 - val_accuracy: 0.9444 - val_loss: 0.1497
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9056 - loss: 0.2191 - val_accuracy: 0.9444 - val_loss: 0.1794
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9377 - loss: 0.1703 - val_accuracy: 0.9722 - val_loss: 0.1483
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9505 - loss: 0.1681 - val_accuracy: 0.9722 - val_loss: 0.1392
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9571 - loss: 0.1670 - val_accuracy: 0.9167 - val_loss: 0.2344
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9297 - loss: 0.1917 - val_accuracy: 0.9444 - val_loss: 0.1513
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9331 - loss: 0.1644 - val_accuracy: 0.9444 - val_loss: 0.1378
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9538 - loss: 0.1754 - val_accuracy: 0.9722 - val_loss: 0.1824
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9311 - loss: 0.1718 - val_accuracy: 0.9722 - val_loss: 0.1420
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9458 - loss: 0.1726 - val_accuracy: 0.9444 - val_loss: 0.1409
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9524 - loss: 0.1443 - val_accuracy: 0.9444 - val_loss: 0.1701
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9458 - loss: 0.1578 - val_accuracy: 0.9722 - val_loss: 0.1520
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9518 - loss: 0.1503 - val_accuracy: 0.9444 - val_loss: 0.1382
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9652 - loss: 0.1318 - val_accuracy: 0.9722 - val_loss: 0.1650
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9505 - loss: 0.1485 - val_accuracy: 0.9722 - val_loss: 0.1607
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9558 - loss: 0.1316 - val_accuracy: 0.9444 - val_loss: 0.1408
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9585 - loss: 0.1476 - val_accuracy: 0.9722 - val_loss: 0.1501
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9458 - loss: 0.1457 - val_accuracy: 0.9722 - val_loss: 0.1576
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9458 - loss: 0.1455 - val_accuracy: 0.9444 - val_loss: 0.1492
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9458 - loss: 0.1455 - val_accuracy: 0.9444 - val_loss: 0.1555
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9358 - loss: 0.1503 - val_accuracy: 0.9722 - val_loss: 0.1384
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9571 - loss: 0.1319 - val_accuracy: 0.9722 - val_loss: 0.1586
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9424 - loss: 0.1482 - val_accuracy: 0.9444 - val_loss: 0.1646
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9552 - loss: 0.1443 - val_accuracy: 0.9444 - val_loss: 0.1463
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9599 - loss: 0.1419 - val_accuracy: 0.9722 - val_loss: 0.1500
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9458 - loss: 0.1350 - val_accuracy: 0.9722 - val_loss: 0.1568
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9424 - loss: 0.1473 - val_accuracy: 0.9444 - val_loss: 0.1405
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9618 - loss: 0.1320 - val_accuracy: 0.9722 - val_loss: 0.1328
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9458 - loss: 0.1432 - val_accuracy: 0.9722 - val_loss: 0.1548
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9391 - loss: 0.1434 - val_accuracy: 0.9444 - val_loss: 0.1523
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9491 - loss: 0.1353 - val_accuracy: 0.9444 - val_loss: 0.1446
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9471 - loss: 0.1385 - val_accuracy: 0.9722 - val_loss: 0.1563
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9444 - loss: 0.1255 - val_accuracy: 0.9722 - val_loss: 0.1330
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9505 - loss: 0.1483 - val_accuracy: 0.9444 - val_loss: 0.1295
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9632 - loss: 0.1383 - val_accuracy: 0.9444 - val_loss: 0.1952
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9358 - loss: 0.1697 - val_accuracy: 0.9722 - val_loss: 0.1434
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9585 - loss: 0.1302 - val_accuracy: 0.9444 - val_loss: 0.1280
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9552 - loss: 0.1460 - val_accuracy: 0.9722 - val_loss: 0.1716
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9538 - loss: 0.1335 - val_accuracy: 0.9167 - val_loss: 0.1581
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9571 - loss: 0.1221 - val_accuracy: 0.9444 - val_loss: 0.1501
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9090 - loss: 0.1719 - val_accuracy: 0.9167 - val_loss: 0.1720
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9411 - loss: 0.1449 - val_accuracy: 0.9722 - val_loss: 0.1662
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9458 - loss: 0.1419 - val_accuracy: 0.9444 - val_loss: 0.1475
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9117 - loss: 0.2182 - val_accuracy: 0.9167 - val_loss: 0.1804
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9397 - loss: 0.1721 - val_accuracy: 0.9444 - val_loss: 0.1390
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9491 - loss: 0.1217 - val_accuracy: 0.9444 - val_loss: 0.2031
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8494 - loss: 0.3219 - val_accuracy: 0.8611 - val_loss: 0.4528
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8334 - loss: 0.3144 - val_accuracy: 0.9444 - val_loss: 0.1386
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9096 - loss: 0.2074 - val_accuracy: 0.9444 - val_loss: 0.1398
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9431 - loss: 0.1431 - val_accuracy: 0.7778 - val_loss: 0.5725
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8381 - loss: 0.3987 - val_accuracy: 0.9167 - val_loss: 0.2989
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7611 - loss: 0.5798 - val_accuracy: 0.8889 - val_loss: 0.2564
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8902 - loss: 0.2322 - val_accuracy: 0.9444 - val_loss: 0.1588
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9571 - loss: 0.1318 - val_accuracy: 0.9167 - val_loss: 0.1917
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8541 - loss: 0.2864 - val_accuracy: 0.8611 - val_loss: 0.2371
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9237 - loss: 0.1903 - val_accuracy: 0.9167 - val_loss: 0.1596
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9679 - loss: 0.1224 - val_accuracy: 0.9167 - val_loss: 0.1406
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# 딕셔너리를 통한 각 모델 시각화

# %%
import matplotlib.pyplot as plt

# 데이터 준비
histories = {
    "Base Model": base_history,
    "Hidden Layer Tuned Model": hidlayer_history,
    "Batch Size Tuned Model": batch_history
}

# Subplot 생성
plt.figure(figsize=(14, 10))  # 전체 그림 크기 설정

# 1번 그래프: 손실 비교
plt.subplot(2, 1, 1)  # 2행 1열 중 첫 번째 그래프
for name, history in histories.items():
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, val_loss, label=f'{name} Validation Loss')
    plt.plot(epochs, loss, linestyle='--', alpha=0.7, label=f'{name} Training Loss')

plt.title('Training and Validation Loss Comparison')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# 2번 그래프: 정확도 비교
plt.subplot(2, 1, 2)  # 2행 1열 중 두 번째 그래프
for name, history in histories.items():
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, val_acc, label=f'{name} Validation Accuracy')
    plt.plot(epochs, acc, linestyle='--', alpha=0.7, label=f'{name} Training Accuracy')

plt.title('Training and Validation Accuracy Comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# 전체 그래프 표시
plt.tight_layout()  # 그래프 간격 자동 조정
plt.show()

# %% [markdown]
# 이상하게도 base model이 생각보다 정확도가 높게 나와서 놀랐다 이유는 알수 없지만..... 더 나중에 비교해보도록 하겠다
